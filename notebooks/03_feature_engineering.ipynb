# %% [markdown]
# # 03 - Feature Engineering
#
# This notebook creates and transforms features for modeling.
#
# ## Objectives:
# - Create new features from existing data
# - Feature scaling and normalization
# - Encoding categorical variables
# - Feature selection
# - Dimensionality reduction (if needed)

# %%
import pandas as pd
import numpy as np
import sys

# Add parent directory to path to import from src
sys.path.append('..')

# Import our custom feature engineer module
from src.features.feature_engineering import FeatureEngineer

# Load preprocessed data
df = pd.read_csv('../data/processed/movies_preprocessed.csv')
print(f"Data shape: {df.shape}")
print(f"Columns: {list(df.columns)}")
print(f"\nFirst few rows:")
df.head()
# Out:
# Data shape: (11242, 22)
# Columns: ['id', 'title', 'release_date', 'budget', 'revenue', 'runtime', 'rating', 'vote_count', 'popularity', 'genres', 'production_companies', 'production_countries', 'director', 'cast', 'keywords', 'original_language', 'collection', 'poster_brightness', 'poster_saturation', 'poster_dom_r', 'poster_dom_g', 'poster_dom_b']
#
# First few rows:
#       id                           title release_date     budget    revenue  \
# 0   2133               The Perfect Storm   2000-06-29  18.683045  19.610712
# 1   8871  How the Grinch Stole Christmas   2000-11-17  18.627695  19.661371
# 2   2655               What Lies Beneath   2000-07-21  18.420681  19.490277
# 3  36657                           X-Men   2000-07-13  18.132999  19.507016
# 4   3981                 What Women Want   2000-12-15  18.064006  19.740034
#
#    runtime  rating  vote_count  popularity  \
# 0      130   6.478        2497      3.4497
# 1      105   6.784        8162      7.1169
# ...

# %%
# Initialize Feature Engineer
# use_post_release_features=False means we only use pre-release features
engineer = FeatureEngineer(use_post_release_features=False)

# Fit and transform the data
print("Applying feature engineering...\n")
df_featured = engineer.fit_transform(df)

print("="*80)
print("FEATURE ENGINEERING COMPLETE")
print("="*80)
print(f"Original shape: {df.shape}")
print(f"Featured shape: {df_featured.shape}")
print(f"Features created: {len(engineer.get_feature_names())}")
print("="*80)

# Show some of the engineered features
print("\nSample of engineered features:")
feature_cols = ['num_production_companies', 'num_genres', 'is_action', 'is_summer', 
                'num_cast', 'has_cast', 'movie_age', 'in_collection']
print(df_featured[feature_cols].head(10))
# Out:
# Applying feature engineering...
#
# ...
# FEATURE ENGINEERING COMPLETE
# ...
# Original shape: (11242, 22)
# Featured shape: (11242, 31)
# Features created: 23
# ...
#
# Sample of engineered features:
#    num_production_companies  num_genres  is_action  is_summer  num_cast  \
# 0                         4           3          1          1         5
# 1                         3           3          0          0         5
# 2                         3           4          0          1         5
# 3                         4           3          1          1         5
# 4                         3           2          0          0         5
# 5                         4           2          0          0         5
# 6                         5           3          1          1         5
# 7                         3           4          0          1         5
# 8                         2           3          1          1         5
# ...

# %%
# Check the final feature set
print("Final feature set information:")
print("="*80)
df_featured.info()

print("\n" + "="*80)
print("FEATURE SUMMARY")
print("="*80)
print(f"Total features (including revenue target): {len(df_featured.columns)}")
print(f"\nFeature list:")
for i, col in enumerate(df_featured.columns, 1):
    print(f"  {i:2d}. {col}")
print("="*80)
# Out:
# Final feature set information:
# ...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11242 entries, 0 to 11241
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   budget                    11242 non-null  float64
#  1   revenue                   11242 non-null  float64
#  2   runtime                   11242 non-null  int64
#  3   poster_brightness         11242 non-null  float64
#  4   poster_saturation         11242 non-null  float64
#  5   poster_dom_r              11242 non-null  float64
#  6   poster_dom_g              11242 non-null  float64
#  7   poster_dom_b              11242 non-null  float64
#  8   num_production_companies  11242 non-null  int64
#  9   num_production_countries  11242 non-null  int64
#  10  budget_per_minute         11242 non-null  float64
#  11  num_genres                11242 non-null  int64
#  12  is_action                 11242 non-null  int64
# ...

# %%
# Visualize some engineered features
import matplotlib.pyplot as plt
import seaborn as sns

fig, axes = plt.subplots(2, 3, figsize=(18, 10))

# 1. Number of genres distribution
axes[0, 0].hist(df_featured['num_genres'], bins=20, color='skyblue', edgecolor='black')
axes[0, 0].set_xlabel('Number of Genres')
axes[0, 0].set_ylabel('Frequency')
axes[0, 0].set_title('Distribution of Genre Count')
axes[0, 0].grid(alpha=0.3)

# 2. Genre flags
genre_flags = ['is_action', 'is_animation', 'is_comedy', 'is_drama', 'is_scifi']
genre_counts = [df_featured[flag].sum() for flag in genre_flags]
axes[0, 1].bar(range(len(genre_flags)), genre_counts, color='coral')
axes[0, 1].set_xticks(range(len(genre_flags)))
axes[0, 1].set_xticklabels(['Action', 'Animation', 'Comedy', 'Drama', 'Sci-Fi'], rotation=45)
axes[0, 1].set_ylabel('Count')
axes[0, 1].set_title('Movies by Genre')
axes[0, 1].grid(axis='y', alpha=0.3)

# 3. Release month distribution
axes[0, 2].hist(df_featured['release_month'], bins=12, color='lightgreen', edgecolor='black')
axes[0, 2].set_xlabel('Release Month')
axes[0, 2].set_ylabel('Frequency')
axes[0, 2].set_title('Distribution of Release Months')
axes[0, 2].set_xticks(range(1, 13))
axes[0, 2].grid(alpha=0.3)

# 4. Seasonal releases
seasonal = ['is_summer', 'is_holiday', 'is_weekend_month']
seasonal_counts = [df_featured[flag].sum() for flag in seasonal]
axes[1, 0].bar(range(len(seasonal)), seasonal_counts, color='orange')
axes[1, 0].set_xticks(range(len(seasonal)))
axes[1, 0].set_xticklabels(['Summer', 'Holiday', 'Weekend'], rotation=45)
axes[1, 0].set_ylabel('Count')
axes[1, 0].set_title('Seasonal Releases')
axes[1, 0].grid(axis='y', alpha=0.3)

# 5. Cast size distribution
axes[1, 1].hist(df_featured['num_cast'], bins=30, color='purple', alpha=0.7, edgecolor='black')
axes[1, 1].set_xlabel('Number of Cast Members')
axes[1, 1].set_ylabel('Frequency')
axes[1, 1].set_title('Distribution of Cast Size')
axes[1, 1].grid(alpha=0.3)

# 6. Movie age distribution
axes[1, 2].hist(df_featured['movie_age'], bins=30, color='teal', alpha=0.7, edgecolor='black')
axes[1, 2].set_xlabel('Movie Age (years)')
axes[1, 2].set_ylabel('Frequency')
axes[1, 2].set_title('Distribution of Movie Age')
axes[1, 2].grid(alpha=0.3)

plt.tight_layout()
plt.show()

# %%
# Save engineered features
output_path = '../data/processed/movies_featured.csv'
df_featured.to_csv(output_path, index=False)

print(f"Shape after feature engineering: {df_featured.shape}")
print(f"Data saved to: {output_path}")
# Out:
# Shape after feature engineering: (11242, 31)
# Data saved to: ../data/processed/movies_featured.csv
